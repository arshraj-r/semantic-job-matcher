# %%
import pandas as pd

# Define keywords with categories
skills_data = {
    "Category": [
        # Tools & Platforms (13 items)
        "Tools & Platforms"] * 13 +
        # ML & DL Frameworks (5 items)
        ["ML & DL Frameworks"] * 5 +
        # NLP & Generative AI (15 items)
        ["NLP & Generative AI"] * 15 +
        # NLP Libraries & Techniques (9 items)
        ["NLP Libraries & Techniques"] * 9 +
        # RAG & Vector Databases (6 items)
        ["RAG & Vector Databases"] * 6 +
        # Data Science & MLOps (13 items)
        ["Data Science & MLOps"] * 13,
    
    "Keyword": [
        # Tools & Platforms (13)
        "Python", "SQL", "SAS", "R", "Docker", "Kubernetes", "Kubeflow", "Git", "GitHub", "Streamlit", "FastAPI", "CI/CD pipelines", "Vertex AI",
        # ML & DL Frameworks (5)
        "TensorFlow", "PyTorch", "Scikit-learn", "Prophet", "HuggingFace",
        # NLP & Generative AI (15)
        "Generative AI", "Large Language Models (LLMs)", "LLM fine-tuning", "Prompt engineering", "Chain of Thought (CoT)",
        "ReAct", "Zero-shot learning", "Few-shot learning", "Text classification", "Sentiment analysis",
        "Named Entity Recognition (NER)", "Topic modeling", "Text summarization", "Language translation", "Hate speech detection",
        # NLP Libraries & Techniques (9)
        "PEFT (Parameter-Efficient Fine-Tuning)", "LoRA (Low-Rank Adaptation)", "SBERT (Sentence-BERT)",
        "Spacy", "NLTK", "Gensim", "Regex", "BERTopic", "LDA (Latent Dirichlet Allocation)",
        # RAG & Vector Databases (6)
        "Retrieval-Augmented Generation (RAG)", "LangChain", "Quadrant", "FAISS", "OpenAI embeddings", "Vector search",
        # Data Science & MLOps (13)
        "Model evaluation", "Model inference", "Anomaly detection", "Time series forecasting",
        "SMTP (email automation)", "MLOps", "Model deployment", "Cloud resource management", "Data preprocessing",
        "Model monitoring", "Statistical Analysis Plans (SAPs)", "Vertex AI", "Google Cloud Platform (GCP)"
    ]
}

# Create DataFrame and save as CSV
skills_df = pd.DataFrame(skills_data)
skills_df.to_csv("cv_skills_keywords.csv", index=False)

# %%
skills_df
# Out:
#                 Category                            Keyword
# 0      Tools & Platforms                             Python
# 1      Tools & Platforms                                SQL
# 2      Tools & Platforms                                SAS
# 3      Tools & Platforms                                  R
# 4      Tools & Platforms                             Docker
# ..                   ...                                ...
# 56  Data Science & MLOps                 Data preprocessing
# 57  Data Science & MLOps                   Model monitoring
# 58  Data Science & MLOps  Statistical Analysis Plans (SAPs)
# 59  Data Science & MLOps                          Vertex AI
# 60  Data Science & MLOps        Google Cloud Platform (GCP)
#
# [61 rows x 2 columns]
