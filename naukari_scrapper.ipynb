# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd


def extract_job_details_from_card(job_element):
    try:
        title_element = job_element.find_element(By.CSS_SELECTOR, 'h2 > a.title')
        title = title_element.text
        job_link = title_element.get_attribute('href')

        company = job_element.find_element(By.CSS_SELECTOR, 'a.comp-name').text
        experience = job_element.find_element(By.CSS_SELECTOR, 'span.expwdth').text
        location = job_element.find_element(By.CSS_SELECTOR, 'span.locWdth').text
        description = job_element.find_element(By.CSS_SELECTOR, 'span.job-desc').text
        post_date = job_element.find_element(By.CSS_SELECTOR, 'span.job-post-day').text

        # Extract skills/tags
        skill_elements = job_element.find_elements(By.CSS_SELECTOR, 'ul.tags-gt > li')
        skills = [skill.text for skill in skill_elements]

        return {
            'Title': title,
            'Company': company,
            'Experience': experience,
            'Location': location,
            'Description': description,
            'Posted': post_date,
            'Skills': ', '.join(skills),
            'Link': job_link
        }
    except Exception as e:
        print(f"Error extracting job details: {e}")
        return None
        




def scrape_naukari_jobs(keywords, location = "bengaluru", experience = 5):        
    options = webdriver.ChromeOptions()
    # options.add_argument('--headless') 
    options.add_argument('--disable-gpu')
    options.add_argument("--start-maximized")
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    all_jobs_df=pd.DataFrame()
    
    for keyword in keywords:
        url = f"https://www.naukri.com/{keyword}-jobs-in-{location}?experience={str(experience)}"
        driver.get(url)
        # Wait until job elements are present
        try:
            WebDriverWait(driver, 15).until(
                EC.presence_of_element_located((By.CLASS_NAME, "srp-jobtuple-wrapper"))
            )
            print("Job elements loaded.")
        except:
            print("Job elements not found or took too long to load.")
        
        # Scroll to trigger more content load
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)
        
        # Now get job cards
        jobs = driver.find_elements(By.CLASS_NAME, 'srp-jobtuple-wrapper')
        print(f"Found {len(jobs)} job elements.")
    
        #inspect html content for each job card
        # job=jobs[0]
        # print(job.get_attribute('innerHTML'))
    
        jobs_data = []
        for job in jobs:
            try:
                job_data=extract_job_details_from_card(job)
                jobs_data.append(job_data)
            except Exception as e:
                print(f"Error: {e}")
        jobs_df=pd.DataFrame(jobs_data)
        all_jobs_df = pd.concat([all_jobs_df, jobs_df], ignore_index=True)
    driver.quit()
    return all_jobs_df

# %%
keywords=["NLP","LLM","Gen AI"]
scrape_naukari_jobs(keywords=keywords,location = "bengaluru", experience = 5)
# Out:
# Job elements loaded.
# Found 20 job elements.
# Job elements loaded.
# Found 20 job elements.
# Job elements loaded.
# Found 20 job elements.
#                                                 Title  \
# 0                   Data Scientist (ML/NLP Developer)
# 1            Senior Machine Learning Engineer NLP/LLM
# 2   Looking For Senior Data Scientist || GEN AI | ...
# 3   Principal Data Scientist / Senior Data Scienti...
# 4       Senior AI / ML Engineer - NLP / Deep Learning
# 5                                  NLP & LLM Engineer
# 6         Senior AI/ML Engineer - NLP & Generative AI
# 7                               Lead NLP/LLM Engineer
# 8   Urgently hiring For AI/ML Engineer (LLM/NLP) M...
# 9               Machine Learning Data Scientist - NLP
# 10  Lead Data Scientist || GEN-AI, LLM, NLP, Conve...
# 11           Lead AIML Engineer - NLP & Generative AI
# 12          Senior Analyst/Data Scientist - NLP/GenAI
# 13   Data Scientist/Senior Data Scientist - NLP GenAi
# 14                                 NLP Engineer | FTE
# 15                        Data Scientist - NLP/Gen AI
# 16      Senior Machine Learning Engineer - NLP/Python
# 17             Senior Machine Learning Engineer (NLP)
# 18              Staff Machine Learning Engineer (NLP)
# 19                               NLP , Data Scientist
# 20                          Data Science- Gen AI- LLM
# 21                                Senior LLM Engineer
# 22           Senior Machine Learning Engineer NLP/LLM
# 23  Looking For Senior Data Scientist || GEN AI | ...
# 24                            LLM Data Scientist Lead
# 25  AI/ML Developer (LLMs & Prompt Engineering) – ...
# 26                              Lead NLP/LLM Engineer
# 27  Manager/Sr. Manager/AD- Large Language Models ...
# 28                                  ML Engineer (LLM)
# 29                        LLM Finetuning Professional
# 30                                 NLP & LLM Engineer
# 31  Lead Data Scientist || GEN-AI, LLM, NLP, Conve...
# 32  Senior LLM Engineer GenAI / ML (Python, Langch...
# 33                                Senior LLM Engineer
# 34  Urgently hiring For AI/ML Engineer (LLM/NLP) M...
# 35                    Machine Learning Engineer - LLM
# 36  Machine Learning Engineer - Computer Vision & LLM
# 37                Solution Architect - UiPath LLM Job
# 38       Senior Devops Engineer with LLM's Experience
# 39        Lead Software Engineer (Python, GenAI, LLM)
# 40  Looking For Senior Data Scientist || GEN AI | ...
# 41                     Senior / Lead AI (Gen AI, MLE)
# 42                                    Gen AI Engineer
# 43                                             GEN AI
# 44                                   GEN AI Developer
# 45                                   Gen AI developer
# 46                                  Gen AI Consultant
# 47                                  GEN AI Consultant
# 48      SaT-DnA-Data Science Gen AI Assistant Manager
# 49                                     Gen AI Experts
# 50                                  Gen AI Specialist
# 51  GEN AI - Engineer/Specialist - Pan India - Imm...
# 52                                          GEN AI/ML
# 53  Data Analysis & Simulation Professional (Gen A...
# 54                                             Gen Ai
# 55  Data Analysis & Simulation Professional (Gen A...
# 56                                        GEN AI Lead
# 57                                     Gen AI Experts
# 58       Data Scientist/Senior Data Scientist_ Gen AI
# 59       Data Scientist/Senior Data Scientist_ Gen AI
#
#                                   Company Experience  \
# 0                              DIGITAP.AI    1-2 Yrs
# 1                           Avalara India    4-8 Yrs
# 2                                 Birdeye    5-9 Yrs
# 3    Benovymed Healthcare Private Limited    0-5 Yrs
# 4                          Leading Client    5-8 Yrs
# 5                             Evalueserve    3-8 Yrs
# 6                                 Siemens   5-10 Yrs
# 7                                  Uplers    5-9 Yrs
# 8                       Kaizenit Infotech  12-19 Yrs
# 9                       Forecastera India    3-7 Yrs
# 10                                Birdeye    4-9 Yrs
# 11                                Siemens    2-7 Yrs
# 12                                Zetwerk    4-6 Yrs
# 13                      Fractal Analytics   5-10 Yrs
# 14                    Nippon Data Systems    3-8 Yrs
# 15                        Tiger Analytics    4-8 Yrs
# 16                      Maimsd Technology    4-7 Yrs
# 17                                   Suki    3-7 Yrs
# 23  Integrate models into real-time and batch data...    3 Days Ago
# 24  Good communication skills with analytical and ...    2 Days Ago
# 25  The ideal candidate should have practical expe...    3 Days Ago
# 26  Senior Machine Learning EngineerExperience: 5 ...    6 Days Ago
# 27  A 15 years full time education is requiredFron...    3 Days Ago
# 28  Location: Bengaluru, Karnataka. Timings: Full ...    9 Days Ago
# 29  Experience with hyperparameter tuning methods ...   11 Days Ago
# 30  Elevate Your Impact Through Innovation and Lea...   12 Days Ago
# 31  Bachelors or Master s in Computer Science, AI,...    8 Days Ago
# 32  . Senior LLM Engineer GenAI / ML (Python, Lang...   12 Days Ago
# 33  Proficient in Python, Langchain, and SQL. . Un...   12 Days Ago
# 34  1.For NLP: Gen AI, Machine Learning, Technical...    6 Days Ago
# 35  . 3+ years experience in machine learning algo...  30+ Days Ago
# 36  Familiarity with LLM architectures like BERT, ...  30+ Days Ago
# 37  Job Summary:We are looking for 8-10yrs experie...  30+ Days Ago
# 38  DevOps++, Kubernetes, Docker, AWS, Cloud Exter...  30+ Days Ago
# 39  Requirements. 7 to 12 years of relevant profes...  30+ Days Ago
# 40  Integrate models into real-time and batch data...    3 Days Ago
# 41  Role & responsibilities As an AI lead speciali...      Just Now
# 42  2 years experience in GenAI and LLM with overa...    2 Days Ago
# 43  Generative AI minimum 1 Yrs( Realtime / Projec...    3 Days Ago
# 44  Skills: ------------------. GitHub Copilot cer...    3 Days Ago
# 45  Generate required data using data generation t...    4 Days Ago
# 46  Must be a Graduate from a Reputed College. Mus...    4 Days Ago
# 47  Job TitleGEN AI Consultant Responsibilities Ro...    6 Days Ago
# 48  The assignments cover a wide range of countrie...    6 Days Ago
# 49  Axtria: -Axtria is a global provider of award-...    5 Days Ago
# 50  Role & responsibilities Hands-on programming a...    3 Days Ago
# 51  . Bachelors or Master s degree in Computer Sci...    9 Days Ago
# 52  Experience with cloud-based machine learning p...    9 Days Ago
# 53  The position is responsible for turning resear...   10 Days Ago
# 54  Cloud Platforms : Extensive experience with Az...   10 Days Ago
# 55  We are seeking for a 5-7-year experience AI en...   11 Days Ago
# 56  Experience with Training BERT, GPT and Megatro...   11 Days Ago
# 57  Axtria: -Axtria is a global provider of award-...   12 Days Ago
# 58  Demonstrate excellent communication skills and...   12 Days Ago
# 59  Demonstrate excellent communication skills and...   12 Days Ago
#
#                                                Skills  \
# 0   deep learning, Computer vision, Risk analytics...
# 1   python, software development, microsoft azure,...
# 2   Generative AI, Nltk, Enterprise AI, Bert, Spac...
# 3   Data Science, Tensorflow, NLP, Data Scientist,...
# 4   NLP, Data Science, Tensorflow, PyTorch, Artifi...
# 5   NLP, Bert, Spacy, Large Language Models, Nltk,...
# 6   python, natural language processing, aiml, art...
# 7   Pytorch, MLOps, LLM, Sagemaker, Vector Databas...
# 8   Data Science, Large Language Model, Natural La...
# 9   Front end, Machine learning, Information retri...
# 10  Generative AI, Nltk, Enterprise AI, Bert, Spac...
# 11  python, production, microsoft azure, stakehold...
# 12  Health insurance, Automation, Business transfo...
# 13  GIT, GCP, Analytical, Software development lif...
# 14  NLP, kore.ai, Javascript, Chatbot, Python, Nat...
# 15  Data Science, Gen AI, Python, NLP, RAG, Bert, ...
# 16  Machine Learning, Data Science, Tensorflow, Az...
# 17  Administration, Backend, C++, Transcription, M...
# 18  Administration, Backend, C++, Transcription, M...
# 19  Computer science, Pharma, Analytical, Machine ...
# 20  Gen Ai, Langchain, LLM, RAG, Data Science, Dat...
# 21  kubernetes, websocket, python development, sof...
# 22  python, software development, microsoft azure,...
# 23  Generative AI, Nltk, Enterprise AI, Bert, Spac...
# 24  LLM, algorithms, python, lstm, nlp, rnn, softw...
# 25  AI, LLM Development, Python, Azure, LLaMA, GPT...
# 26  Pytorch, MLOps, LLM, Sagemaker, Vector Databas...
# 27  AI/ML, LLMs, Artificial Intelligence, Cloud, L...
# 28  Analytical skills, Data management, GCP, Analy...
# 29  Python, tensorflow, LLM Finetuning, optimizati...
# 30  NLP, Bert, Spacy, Large Language Models, Nltk,...
# 31  Generative AI, Nltk, Enterprise AI, Bert, Spac...
# 32  GEN AI, LLM, ML, Python, Gen, Artificial Intel...
# 33  Machine Learning, Azure, MLOps, GCP, AWS, Arti...
# 34  Data Science, Large Language Model, Natural La...
# 35  Supply chain, Operations research, orchestrati...
# 36  Computer science, Product quality, Computer vi...
# 37  Computer science, Analytical skills, Architect...
# 38  Docker, Aws Cloud, devops, Kubernetes, AWS, Se...
# 39  Photography, CSR, Lead Software, Analytical, M...
# 40  Generative AI, Nltk, Enterprise AI, Bert, Spac...
# 41  Gen AI, MLE, AI, NLP, Deployment, LLM, Natural...
# 42  Computer science, Cloud computing, advanced an...
# 43  Generative AI, SAGEMAKER, Machine Learning, AW...
# 44  python, natural language processing, aiml, art...
# 45  Gen AI, python, Deep Learning, Artificial Inte...
# 46  python, Generative AI, PyTorch, TensorFlow, Cl...
# 47  deep learning, python, natural language proces...
# 48  Supply chain, Telecom, Automation, Business an...
# 49  Generative Ai, Model Building, Python, SQL, Mo...
# 50  AI, Gen AI, ML, Generative AI, Artificial Inte...
# 51  Generative Ai, LLM, Machine Learning, Python, ...
# 52  NoSQL, Data modeling, Social media, Machine le...
# 53  python, data processing, machine learning, aws...
# 54  Crew Ai, Wren Ai, Gen Ai, Autogen, Generative ...
# 55  Automation, Data analysis, Simulation, Data mo...
# 56  Training, deep learning, Software design, Tran...
# 57  Generative Ai, Model Building, Python, SQL, Mo...
# 58  GIT, GCP, Analytical, Software development lif...
# 59  GIT, GCP, Analytical, Software development lif...
#
#                                                  Link
# 0   https://www.naukri.com/job-listings-data-scien...
# 1   https://www.naukri.com/job-listings-senior-mac...
# 2   https://www.naukri.com/job-listings-looking-fo...
# 3   https://www.naukri.com/job-listings-principal-...
# 4   https://www.naukri.com/job-listings-senior-ai-...
