# %%
import pandas as pd
from app.linkedin_scraper import   scrape_jobs_for_keywords,scrape_jd_from_url
from app.resume_parser import extract_text_from_resume  
from app.similarity_score import  similarity_score_calculator

# %%
location="Bengaluru"
keywords=["NLP", "Gen AI"]
scroll_page=2
jobs = scrape_jobs_for_keywords(job_keywords=keywords, location=location, scroll_page=scroll_page)
jobs.to_csv("daily_jobs/jobs_df.csv",index=False)
# Out:
# 🔍 Searching for: LLM
# Total job cards found for keyword LLM are:20
#
# 🔍 Searching for: NLP
# Total job cards found for keyword NLP are:24
#
# 🔍 Searching for: Gen AI
# Total job cards found for keyword Gen AI are:31
#
# 🔍 Searching for: Data Scientist
# Total job cards found for keyword Data Scientist are:100

# %%
jobs=pd.read_csv("daily_jobs/jobs_df.csv")
jobs=jobs[:10]
print(f"running code for: {jobs.shape[0]}")
for i in range(jobs.shape[0]):
    link=jobs["link"].values[i]
# Out:
# running code for: 10

# %%
jobs["JD"]=jobs["link"].apply(scrape_jd_from_url)
# Out:
# Popup detected. Clicking outside to dismiss.
# Clicked 'Show more' button.
# Popup detected. Clicking outside to dismiss.
# Clicked 'Show more' button.
# Popup detected. Clicking outside to dismiss.
# Clicked 'Show more' button.
# Popup detected. Clicking outside to dismiss.
# Clicked 'Show more' button.
# Popup detected. Clicking outside to dismiss.
# Clicked 'Show more' button.
# Popup detected. Clicking outside to dismiss.
# Clicked 'Show more' button.
# Popup detected. Clicking outside to dismiss.
# Clicked 'Show more' button.
# Popup detected. Clicking outside to dismiss.
# Clicked 'Show more' button.
# Popup detected. Clicking outside to dismiss.
# Clicked 'Show more' button.
# Popup detected. Clicking outside to dismiss.
# Clicked 'Show more' button.

# %%
# Out:
#                                                title  \
# 0                          PRINCIPAL, DATA SCIENTIST
# 1                                Senior LLM Engineer
# 2                                      Legal Manager
# 3                                      LLM Scientist
# 4              Conversational AI Performance Analyst
# 5  Senior LLM Engineer (With ML and Prompt Engg Exp)
# 6  Manager, Applied Science, Conversational Assis...
# 7                                       LLM Engineer
# 8                                       QE Architect
# 9                                   Senior Architect
#
#                                        company  \
# 0                    Walmart Global Tech India
# 1                                     SciSpace
# 2  Vestian Global Workplace Services Pvt. Ltd.
# 3                                   Prana Tree
# 4                                     Verifast
# 5                                     SciSpace
# 6                                       Amazon
# 7                                       micro1
# 8                       Jijivisha HR Solutions
# 9                              Greenway Health
#
#                                                 link keyword  \
# 0  https://in.linkedin.com/jobs/view/principal-da...     LLM
# 1  https://in.linkedin.com/jobs/view/senior-llm-e...     LLM
# 2  https://in.linkedin.com/jobs/view/legal-manage...     LLM
# 3  https://in.linkedin.com/jobs/view/llm-scientis...     LLM
# 4  https://in.linkedin.com/jobs/view/conversation...     LLM
# 5  https://in.linkedin.com/jobs/view/senior-llm-e...     LLM
# 6  https://in.linkedin.com/jobs/view/manager-appl...     LLM
# 7  https://in.linkedin.com/jobs/view/llm-engineer...     LLM
# 8  https://in.linkedin.com/jobs/view/qe-architect...     LLM
# 9  https://in.linkedin.com/jobs/view/senior-archi...     LLM
#
#                                                   JD
# 0  Position Summary...\n\nWhat you'll do...\n\nRo...
# 1  Responsibilities\n\nPrompt Engineering Techniq...
# 2  Assistant Manager – Legal Services\nExperience...
# 3  Job description\nPranatree LLC is seeking an e...
# 4  About the Company:\nVerifast is a dynamic and ...
# 5  Responsibilities\n\nPrompt Engineering Techniq...
# 6  Description\n\nThe AI Domains org within the A...
# 7  Job Title: LLM Scientist\n\nJob Type: Full-tim...
# 8  Job Summary: One of our clients HQ in US is se...
# 9  Location: Bangalore\nJob Type: Full-time\nExpe...

# %%
jobs.to_csv("daily_jobs/jobs_df.csv",index=False)

# %%
jobs
# Out:
#                                                title  \
# 0                          PRINCIPAL, DATA SCIENTIST
# 1                                Senior LLM Engineer
# 2                                      Legal Manager
# 3                                      LLM Scientist
# 4              Conversational AI Performance Analyst
# 5  Senior LLM Engineer (With ML and Prompt Engg Exp)
# 6  Manager, Applied Science, Conversational Assis...
# 7                                       LLM Engineer
# 8                                       QE Architect
# 9                                   Senior Architect
#
#                                        company  \
# 0                    Walmart Global Tech India
# 1                                     SciSpace
# 2  Vestian Global Workplace Services Pvt. Ltd.
# 3                                   Prana Tree
# 4                                     Verifast
# 5                                     SciSpace
# 6                                       Amazon
# 7                                       micro1
# 8                       Jijivisha HR Solutions
# 9                              Greenway Health
#
#                                                 link keyword  \
# 0  https://in.linkedin.com/jobs/view/principal-da...     LLM
# 1  https://in.linkedin.com/jobs/view/senior-llm-e...     LLM
# 2  https://in.linkedin.com/jobs/view/legal-manage...     LLM
# 3  https://in.linkedin.com/jobs/view/llm-scientis...     LLM
# 4  https://in.linkedin.com/jobs/view/conversation...     LLM
# 5  https://in.linkedin.com/jobs/view/senior-llm-e...     LLM
# 6  https://in.linkedin.com/jobs/view/manager-appl...     LLM
# 7  https://in.linkedin.com/jobs/view/llm-engineer...     LLM
# 8  https://in.linkedin.com/jobs/view/qe-architect...     LLM
# 9  https://in.linkedin.com/jobs/view/senior-archi...     LLM
#
#                                                   JD
# 0  Position Summary...\n\nWhat you'll do...\n\nRo...
# 1  Responsibilities\n\nPrompt Engineering Techniq...
# 2  Assistant Manager – Legal Services\nExperience...
# 3  Job description\nPranatree LLC is seeking an e...
# 4  About the Company:\nVerifast is a dynamic and ...
# 5  Responsibilities\n\nPrompt Engineering Techniq...
# 6  Description\n\nThe AI Domains org within the A...
# 7  Job Title: LLM Scientist\n\nJob Type: Full-tim...
# 8  Job Summary: One of our clients HQ in US is se...
# 9  Location: Bangalore\nJob Type: Full-time\nExpe...
